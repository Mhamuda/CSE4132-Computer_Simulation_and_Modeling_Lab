# %%
pip install pandas numpy matplotlib statsmodels
# Out:
# Requirement already satisfied: pandas in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (1.26.2)
# Requirement already satisfied: matplotlib in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: statsmodels in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.11.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: six in c:\users\mhamu\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('shampoo.csv')
df.head()
# Out:
#      Month   Sale
# 0  2021-01  266.0
# 1  2021-02  145.9
# 2  2021-03  183.1
# 3  2021-04  119.3
# 4  2021-05  180.3

# %%
df.dropna()
df.plot()
# Out:
# <Axes: >

# %%
df["Month"] = pd.to_datetime(df["Month"])
df.plot()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#        Month   Sale
# 0 2021-01-01  266.0
# 1 2021-02-01  145.9
# 2 2021-03-01  183.1
# 3 2021-04-01  119.3
# 4 2021-05-01  180.3

# %%
df = df.set_index("Month")
df.head()
# Out:
#              Sale
# Month
# 2021-01-01  266.0
# 2021-02-01  145.9
# 2021-03-01  183.1
# 2021-04-01  119.3
# 2021-05-01  180.3

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# test_result = adfuller(df["Sale"])
def adfulller_test(sale):
    result = adfuller(sale)
    if(result[1] < 0.05):
        print(f"p-value = {result[1]}, so the data is Stationary.")
    else:
        print(f"p-value = {result[1]}, so the data is Non-Stationary.")

# %%
adfulller_test(df["Sale"])
# Out:
# p-value = 1.0, so the data is Non-Stationary.

# %%
firstOrderDiff = df - df.shift(1) # shift moves the data down by 1
firstOrderDiff = firstOrderDiff.dropna()
firstOrderDiff.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
adfulller_test(firstOrderDiff["Sale"])
d = 1
# Out:
# p-value = 1.7998574141687034e-10, so the data is Stationary.

# %%
secondOrderDiff = firstOrderDiff - firstOrderDiff.shift(1)
secondOrderDiff = secondOrderDiff.dropna()
secondOrderDiff.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
adfulller_test(secondOrderDiff["Sale"])
# Out:
# p-value = 0.003906334939659565, so the data is Stationary.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
# plot_acf(df, lags=20, ax=ax1)
# plot_pacf(df, ax=ax2)

plot_acf(df, lags=20)
plot_pacf(df)
plt.show()

# %%
p = 2
q = 3

# %%
from statsmodels.tsa.arima.model import ARIMA

train_size = int(len(df) * 0.66)    # 66% of data is used for training
train = df[ : train_size]
test = df[train_size: ]

model = ARIMA(train, order=(p, d, q))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   Sale   No. Observations:                   23
# Model:                 ARIMA(2, 1, 3)   Log Likelihood                -123.019
# Date:                Thu, 25 Jan 2024   AIC                            258.038
# Time:                        04:39:27   BIC                            264.585
# Sample:                    01-01-2021   HQIC                           259.580
#                          - 11-01-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0580      1.169      0.050      0.960      -2.233       2.349
# ar.L2          0.7819      1.117      0.700      0.484      -1.407       2.971
# ma.L1         -0.9858      1.358     -0.726      0.468      -3.647       1.675
# ma.L2         -0.3360      1.047     -0.321      0.748      -2.389       1.717
# ma.L3          0.4392      0.847      0.518      0.604      -1.221       2.100
# sigma2      3960.3462   2198.113      1.802      0.072    -347.877    8268.569
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                 1.28
# Prob(Q):                              0.85   Prob(JB):                         0.53
# Heteroskedasticity (H):               1.54   Skew:                             0.50
# Prob(H) (two-sided):                  0.58   Kurtosis:                         2.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
prediction = model_fit.predict(start=len(train), end=len(df)-1)
print(prediction)
# Out:
# 2022-12-01    358.914928
# 2023-01-01    309.091835
# 2023-02-01    369.733288
# 2023-03-01    334.296566
# 2023-04-01    379.653699
# 2023-05-01    354.578412
# 2023-06-01    388.586487
# 2023-07-01    370.953996
# 2023-08-01    396.520509
# 2023-09-01    384.217523
# 2023-10-01    403.493121
# 2023-11-01    394.992110
# 2023-12-01    409.569678
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
plt.plot(df, color='green', label= "Actual data")
plt.plot(prediction, color='red', label= "Predicted data")
plt.title("Actual data vs Predicted data")
plt.xlabel("Time")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
import statsmodels.api as sm

model = sm.tsa.statespace.SARIMAX(train, order=(p,d,q), seasonal_order=(p,d,q,24))
model_fit = model.fit()
# print(model_fit.summary())

prediction = model_fit.predict(start=len(train), end=len(df)-1)
print(prediction)
# Out:
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\mhamu\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# 2022-12-01    264.500000
# 2023-01-01    397.500066
# 2023-02-01    277.400066
# 2023-03-01    314.600066
# 2023-04-01    250.800066
# 2023-05-01    311.800066
# 2023-06-01    300.000066
# 2023-07-01    363.300066
# 2023-08-01    356.000066
# 2023-09-01    324.300066
# 2023-10-01    254.400066
# 2023-11-01    468.000066
# 2023-12-01    317.400066
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
plt.plot(df, color='green', label= "Actual data")
plt.plot(prediction, color='red', label= "Predicted data")
plt.title("Actual data vs Predicted data")
plt.xlabel("Time")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
future_prediction = model_fit.predict(start=len(df),end=len(df)+12)
plt.plot(df, color='green', label= "Actual data")
plt.plot(prediction, color='red', label= "Predicted data")
plt.plot(future_prediction, color='cyan', label= "Future prediction")
plt.title("Forecasting for next 12 months")
plt.xlabel("Time")
plt.ylabel("Sales")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(test, prediction)
rmse = (mse)**0.5

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 34171.54074275948
# Root Mean Squared Error: 184.85545905587824
